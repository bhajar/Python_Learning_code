# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 50)

# https://www.kaggle.com/antgoldbloom/d/lukebyrne/horses-for-courses/xgboost-vs-betting-markets

# %%
df_market = pd.read_csv("C:/Users/309292/Downloads/horses-for-courses/markets.csv")
df_runners = pd.read_csv("C:/Users/309292/Downloads/horses-for-courses/runners.csv",dtype={'barrier': np.int16,'handicap_weight': np.float16})

# %%
df_market.head(5)
# Out:
#    id             timezone  venue_id  race_number  distance  condition_id  \
# 0   1  2016-06-27 03:00:00         1            3      1200             1
# 1   2  2016-06-27 03:05:00         2            2      1200             2
# 2   3  2016-06-27 03:30:00         1            4      1400             1
# 3   4  2016-06-27 03:40:00         2            3      1400             2
# 4   5  2016-06-27 04:00:00         1            5      1600             1
#
#    weather_id  total_pool_one_win  total_pool_one_place  total_pool_two_win  \
# 0           1            29718.08                   NaN             11564.5
# 1           2            16169.99                   NaN             12624.0
# 2           1            12282.57                   NaN             13233.0
# 3           2            13000.05                   NaN             14416.5
# 4           1            16194.21                   NaN             16076.5
#
# ...

# %%
df_runners.head(5)
# Out:
#    id                collected_at  market_id  position  place_paid  margin  \
# 0   4  2016-06-27 02:54:31.800293          1       NaN           1     NaN
# 1   2  2016-06-27 02:54:31.765863          1       NaN           1     NaN
# 2   5  2016-06-27 02:54:31.835329          1       NaN           0     NaN
# 3  10  2016-06-27 02:54:31.974395          1       NaN           0     NaN
# 4   6  2016-06-27 02:54:31.873492          1       NaN           0     NaN
#
#    horse_id  trainer_id  rider_id  handicap_weight  number  barrier blinkers  \
# 0         4         4.0       4.0             58.5       4       10        f
# 1         2         2.0       2.0             58.5       2        3        f
# 2         5         5.0       5.0             56.5       5        5        f
# 3        10         4.0      10.0             56.5      10       11        f
# 4         6         6.0       6.0             56.5       6       12        f
#
# ...
